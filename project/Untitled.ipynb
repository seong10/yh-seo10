# %%
import pandas as pd

# %%
df = pd.read_csv('KS_NFA_FTNESS_MESURE_MVN_PRSCRPTN_GNRLZ_INFO_202203.csv')

# %%
df.iloc[ : , 10 : ].head()
# Out:
#    MESURE_IEM_001_VALUE  MESURE_IEM_002_VALUE  MESURE_IEM_003_VALUE  \
# 0                 174.8                  74.6                  20.8
# 1                 179.3                  77.0                  18.9
# 2                 156.7                  82.3                  44.4
# 3                 175.6                  65.5                  28.7
# 4                 175.2                  66.0                  18.0
#
#    MESURE_IEM_004_VALUE  MESURE_IEM_005_VALUE  MESURE_IEM_006_VALUE  \
# 0                  91.5                  91.0                 139.0
# 1                  76.0                  61.0                 119.0
# 2                   NaN                  94.0                 153.0
# 3                  86.7                  75.0                 103.0
# 4                   NaN                  86.0                 120.0
#
#    MESURE_IEM_007_VALUE  MESURE_IEM_008_VALUE  MESURE_IEM_009_VALUE  \
# 0                  48.1                  51.1                   NaN
# ...

# %%
notnull = df.iloc[ : , 10 : ].notnull()

# %%
notnull
# Out:
#        MESURE_IEM_001_VALUE  MESURE_IEM_002_VALUE  MESURE_IEM_003_VALUE  \
# 0                      True                  True                  True
# 1                      True                  True                  True
# 2                      True                  True                  True
# 3                      True                  True                  True
# 4                      True                  True                  True
# ...                     ...                   ...                   ...
# 14059                  True                  True                  True
# 14060                  True                  True                  True
# 14061                  True                  True                  True
# 14062                  True                  True                  True
# 14063                  True                  True                  True
#
#        MESURE_IEM_004_VALUE  MESURE_IEM_005_VALUE  MESURE_IEM_006_VALUE  \
# ...

# %%
df.loc[ : , notnull]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7512/1752156488.py in <module>
# ----> 1 df.loc[ : , notnull]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...
