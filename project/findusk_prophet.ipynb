# %%
import pandas as pd

# %%
pd.read_csv('rn_2022.csv', encoding='euc-kr')
# Out:
#                       강수분석 Unnamed: 1 Unnamed: 2
# 0                   [검색조건]        NaN        NaN
# 1                 자료구분 : 일        NaN        NaN
# 2                자료형태 : 기본        NaN        NaN
# 3               지역/지점 : 서울        NaN        NaN
# 4   기간 : 20220425~20220524        NaN        NaN
# 5                      NaN        NaN        NaN
# 6                       날짜         지점    강수량(mm)
# 7               2022-04-25        108        1.3
# 8               2022-04-26        108          1
# 9               2022-04-27        108        NaN
# 10              2022-04-28        108          0
# 11              2022-04-29        108       15.5
# 12              2022-04-30        108        NaN
# 13              2022-05-01        108        NaN
# 14              2022-05-02        108        NaN
# 15              2022-05-03        108        NaN
# 16              2022-05-04        108        NaN
# 17              2022-05-05        108        NaN
# ...

# %%
df = pd.read_csv('대기질측정정보(2019년).csv')

# %%
df
# Out:
#          시군코드  시군명      측정소명    설치년도   측정망명             측정일시각  아황산가스농도값  \
# 0       41820  가평군        가평  2010.0   도시대기  2019-12-31 24:00     0.004
# 1       41280  고양시  백마로(마두역)  2004.0  도로변대기  2019-12-31 24:00     0.003
# 2       41280  고양시       식사동  2002.0   도시대기  2019-12-31 24:00     0.003
# 3       41280  고양시       신원동  2016.0   도시대기  2019-12-31 24:00     0.007
# 4       41280  고양시       주엽동  2018.0   도시대기  2019-12-31 24:00     0.003
# ...       ...  ...       ...     ...    ...               ...       ...
# 815428  41590  화성시       남양읍     NaN   도시대기  2019-01-01 01:00     0.003
# 815429  41590  화성시        동탄     NaN   도시대기  2019-01-01 01:00     0.003
# 815430  41590  화성시       우정읍     NaN   도시대기  2019-01-01 01:00     0.002
# 815431  41590  화성시       청계동  2018.0   도시대기  2019-01-01 01:00     0.004
# 815432  41590  화성시       향남읍     NaN   도시대기  2019-01-01 01:00     0.003
#
#         일산화탄소농도값  오존농도값  이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값
# ...

# %%
df = df.groupby('시군명')['아황산가스농도값', '일산화탄소농도값', '오존농도값',
     '이산화질소농도값', '미세먼지PM10농도값', '미세먼지PM2.5농도값'].mean()
# Out:
# C:\Users\-\AppData\Local\Temp/ipykernel_1252/121887482.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df = df.groupby('시군명')['아황산가스농도값', '일산화탄소농도값', '오존농도값',

# %%
df
# Out:
#       아황산가스농도값  일산화탄소농도값     오존농도값  이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값
# 시군명
# 가평군   0.003306  0.452327  0.028788  0.011012    32.269860     19.521019
# 고양시   0.003617  0.479440  0.028511  0.022422    46.249278     25.890895
# 과천시   0.003458  0.604482  0.024121  0.027413    44.496612     21.773890
# 광명시   0.003335  0.539361  0.027107  0.032184    48.194850     25.228596
# 광주시   0.003716  0.550041  0.023010  0.027190    47.481210     26.089900
# 구리시   0.003237  0.400459  0.026097  0.023649    45.113665     25.718412
# 군포시   0.003793  0.465993  0.028549  0.026254    50.490362     25.043334
# 김포시   0.003468  0.389926  0.031709  0.016176    46.798101     26.200935
# 남양주시  0.003019  0.486573  0.026645  0.021940    43.084163     24.879299
# 동두천시  0.003929  0.401154  0.030808  0.015464    43.247049     25.369355
# 부천시   0.004965  0.529346  0.024800  0.029254    54.752938     32.670581
# 성남시   0.003342  0.618114  0.023654  0.032784    43.395162     23.683875
# ...

# %%
df['측정일시각'].nunique()
# Out:
# 8567

# %%
df2
# Out:
#        년도   시군명  전체온실가스배출량  대상업체및사업장통계  \
# 0    2012   부천시     337034           1
# 1    2012   성남시    8294836           8
# 2    2012   수원시   12085212           5
# 3    2012   시흥시    1423864           8
# 4    2012   안산시    6350842          18
# ..    ...   ...        ...         ...
# 238  2012   구리시      81544           0
# 239  2012   군포시     131412           1
# 240  2012   김포시      79074           0
# 241  2012  남양주시     348648           0
# 242  2012  동두천시    2107264           0
#
#                                                   통계업종
# 0         반도체.디스플레이.전기전자, 발전에너지, 비철금속, 조선, 철강, 통신, 폐기물
# 1                        반도체.디스플레이.전기전자, 폐기물, 건물, 석유화학
# 2            반도체.디스플레이.전기전자, 비철금속, 석유화학, 음식료품, 제지, 폐기물
# 3    기계, 반도체.디스플레이.전기전자, 발전에너지, 석유화학, 섬유, 유리 · 요업, ...
# 4                                       반도체.디스플레이.전기전자
# ..                                                 ...
# 238                                                 제지
# ...

# %%
df2 = df2.loc[ df2['년도'] == 2019 , ['시군명', '전체온실가스배출량'] ]

# %%
df2['년도'].unique()
# Out:
# array([2012, 2011, 2019, 2018, 2017, 2016, 2015, 2014, 2013], dtype=int64)

# %%
df2['시군명'].nunique()
# Out:
# 27

# %%
df2 = pd.read_csv('2경기도시군별온실가스배출량.csv', encoding='euc-kr')

# %%
df2['시군명'].unique()
# Out:
# array(['부천시', '성남시', '수원시', '시흥시', '안산시', '안성시', '안양시', '양주시', '여주시',
#        '오산시', '용인시', '의정부시', '이천시', '파주시', '평택시', '포천시', '하남시', '화성시',
#        '고양시', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시', '남양주시', '동두천시'],
#       dtype=object)

# %%
df2['시군명'].nunique()
# Out:
# 27

# %%
df = df.reset_index()

# %%
df
# Out:
#      시군명  아황산가스농도값  일산화탄소농도값     오존농도값  이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값
# 0    가평군  0.003306  0.452327  0.028788  0.011012    32.269860     19.521019
# 1    고양시  0.003617  0.479440  0.028511  0.022422    46.249278     25.890895
# 2    과천시  0.003458  0.604482  0.024121  0.027413    44.496612     21.773890
# 3    광명시  0.003335  0.539361  0.027107  0.032184    48.194850     25.228596
# 4    광주시  0.003716  0.550041  0.023010  0.027190    47.481210     26.089900
# 5    구리시  0.003237  0.400459  0.026097  0.023649    45.113665     25.718412
# 6    군포시  0.003793  0.465993  0.028549  0.026254    50.490362     25.043334
# 7    김포시  0.003468  0.389926  0.031709  0.016176    46.798101     26.200935
# 8   남양주시  0.003019  0.486573  0.026645  0.021940    43.084163     24.879299
# 9   동두천시  0.003929  0.401154  0.030808  0.015464    43.247049     25.369355
# 10   부천시  0.004965  0.529346  0.024800  0.029254    54.752938     32.670581
# ...

# %%
df2.reset_index()
# Out:
#     index   시군명  전체온실가스배출량
# 0      45   고양시     247921
# 1      46   과천시     698331
# 2      47   광명시     155757
# 3      48   광주시     365878
# 4      49   구리시      81544
# 5      50   군포시     131412
# 6      51   김포시      79074
# 7      52  남양주시     348648
# 8      53  동두천시    2107264
# 9      54   부천시     337034
# 10     55   성남시    8294836
# 11     56   수원시   12085212
# 12     57   시흥시    1423864
# 13     58   안산시    6350842
# 14     59   안성시     116403
# 15     60   안양시    2394670
# 16     61   양주시     534041
# 17     62   여주시      50581
# 18     63   오산시    1351391
# 19     64   용인시    6473669
# 20     65  의정부시      88388
# 21     66   이천시    4488020
# 22     67   파주시    4823291
# 23     68   평택시    2917486
# 24     69   포천시    2550629
# 25     70   하남시    1825488
# 26     71   화성시     891719

# %%
df['시군명'].nunique()
# Out:
# 31

# %%
df2['시군명'].nunique()
# Out:
# 27

# %%
df_last = pd.merge( df, df2, on= '시군명' )

# %%
df_last
# Out:
#      시군명  아황산가스농도값  일산화탄소농도값     오존농도값  이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값  \
# 0    고양시  0.003617  0.479440  0.028511  0.022422    46.249278     25.890895
# 1    과천시  0.003458  0.604482  0.024121  0.027413    44.496612     21.773890
# 2    광명시  0.003335  0.539361  0.027107  0.032184    48.194850     25.228596
# 3    광주시  0.003716  0.550041  0.023010  0.027190    47.481210     26.089900
# 4    구리시  0.003237  0.400459  0.026097  0.023649    45.113665     25.718412
# 5    군포시  0.003793  0.465993  0.028549  0.026254    50.490362     25.043334
# 6    김포시  0.003468  0.389926  0.031709  0.016176    46.798101     26.200935
# 7   남양주시  0.003019  0.486573  0.026645  0.021940    43.084163     24.879299
# 8   동두천시  0.003929  0.401154  0.030808  0.015464    43.247049     25.369355
# 9    부천시  0.004965  0.529346  0.024800  0.029254    54.752938     32.670581
# 10   성남시  0.003342  0.618114  0.023654  0.032784    43.395162     23.683875
# ...

# %%
df_last.describe()
# Out:
#         아황산가스농도값   일산화탄소농도값      오존농도값   이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값  \
# count  27.000000  27.000000  27.000000  27.000000    27.000000     27.000000
# mean    0.003556   0.493567   0.027789   0.023314    46.322568     26.015015
# std     0.000624   0.066491   0.002921   0.005962     3.466239      2.974392
# min     0.002633   0.389926   0.023010   0.011774    40.784057     20.580476
# 25%     0.003190   0.437521   0.025385   0.017965    43.821189     24.170272
# 50%     0.003458   0.486573   0.027641   0.024719    46.249278     25.369355
# 75%     0.003832   0.534338   0.030497   0.027867    47.558145     27.402862
# max     0.004965   0.618114   0.032703   0.032784    54.752938     33.087291
#
#           전체온실가스배출량
# count  2.700000e+01
# mean   2.267163e+06
# std    3.013938e+06
# min    5.058100e+04
# 25%    2.018390e+05
# 50%    8.917190e+05
# 75%    2.734058e+06
# max    1.208521e+07

# %%
df_last.corr()
# Out:
#               아황산가스농도값  일산화탄소농도값     오존농도값  이산화질소농도값  미세먼지PM10농도값  \
# 아황산가스농도값      1.000000  0.001875 -0.116684  0.196012     0.534841
# 일산화탄소농도값      0.001875  1.000000 -0.642969  0.675106    -0.059745
# 오존농도값        -0.116684 -0.642969  1.000000 -0.841649     0.031117
# 이산화질소농도값      0.196012  0.675106 -0.841649  1.000000     0.084666
# 미세먼지PM10농도값   0.534841 -0.059745  0.031117  0.084666     1.000000
# 미세먼지PM2.5농도값  0.385542 -0.170190  0.208047 -0.266409     0.661794
# 전체온실가스배출량    -0.164196  0.364998 -0.204642  0.218226    -0.275016
#
#               미세먼지PM2.5농도값  전체온실가스배출량
# 아황산가스농도값          0.385542  -0.164196
# 일산화탄소농도값         -0.170190   0.364998
# 오존농도값             0.208047  -0.204642
# 이산화질소농도값         -0.266409   0.218226
# 미세먼지PM10농도값       0.661794  -0.275016
# 미세먼지PM2.5농도값      1.000000  -0.243495
# 전체온실가스배출량        -0.243495   1.000000

# %%
df_last.iloc[0, :]
# Out:
# 시군명                   고양시
# 아황산가스농도값         0.003617
# 일산화탄소농도값          0.47944
# 오존농도값            0.028511
# 이산화질소농도값         0.022422
# 미세먼지PM10농도값     46.249278
# 미세먼지PM2.5농도값    25.890895
# 전체온실가스배출량          247921
# Name: 0, dtype: object

# %%
import seaborn as sb

import matplotlib.pyplot as plt

# %%
sb.heatmap(data= df_last.corr(), annot=True, fmt='.2f', 
           vmin = -1, vmax = 1, cmap='coolwarm', linewidths=0.5)
plt.show()

# %%
df_last
# Out:
#      시군명  아황산가스농도값  일산화탄소농도값     오존농도값  이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값  \
# 0    고양시  0.003617  0.479440  0.028511  0.022422    46.249278     25.890895
# 1    과천시  0.003458  0.604482  0.024121  0.027413    44.496612     21.773890
# 2    광명시  0.003335  0.539361  0.027107  0.032184    48.194850     25.228596
# 3    광주시  0.003716  0.550041  0.023010  0.027190    47.481210     26.089900
# 4    구리시  0.003237  0.400459  0.026097  0.023649    45.113665     25.718412
# 5    군포시  0.003793  0.465993  0.028549  0.026254    50.490362     25.043334
# 6    김포시  0.003468  0.389926  0.031709  0.016176    46.798101     26.200935
# 7   남양주시  0.003019  0.486573  0.026645  0.021940    43.084163     24.879299
# 8   동두천시  0.003929  0.401154  0.030808  0.015464    43.247049     25.369355
# 9    부천시  0.004965  0.529346  0.024800  0.029254    54.752938     32.670581
# 10   성남시  0.003342  0.618114  0.023654  0.032784    43.395162     23.683875
# ...

# %%
df_last.to_csv('df.csv')

# %%
df_last = df_last.set_index('시군명')

# %%
df_last
# Out:
#       아황산가스농도값  일산화탄소농도값     오존농도값  이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값  \
# 시군명
# 고양시   0.003617  0.479440  0.028511  0.022422    46.249278     25.890895
# 과천시   0.003458  0.604482  0.024121  0.027413    44.496612     21.773890
# 광명시   0.003335  0.539361  0.027107  0.032184    48.194850     25.228596
# 광주시   0.003716  0.550041  0.023010  0.027190    47.481210     26.089900
# 구리시   0.003237  0.400459  0.026097  0.023649    45.113665     25.718412
# 군포시   0.003793  0.465993  0.028549  0.026254    50.490362     25.043334
# 김포시   0.003468  0.389926  0.031709  0.016176    46.798101     26.200935
# 남양주시  0.003019  0.486573  0.026645  0.021940    43.084163     24.879299
# 동두천시  0.003929  0.401154  0.030808  0.015464    43.247049     25.369355
# 부천시   0.004965  0.529346  0.024800  0.029254    54.752938     32.670581
# 성남시   0.003342  0.618114  0.023654  0.032784    43.395162     23.683875
# 수원시   0.003274  0.616823  0.025057  0.029663    43.788240     24.656669
# ...

# %%
df_last = df_last.reset_index()

# %%
df_last
# Out:
#       아황산가스농도값  일산화탄소농도값     오존농도값  이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값  \
# 시군명
# 고양시   0.003617  0.479440  0.028511  0.022422    46.249278     25.890895
# 과천시   0.003458  0.604482  0.024121  0.027413    44.496612     21.773890
# 광명시   0.003335  0.539361  0.027107  0.032184    48.194850     25.228596
# 광주시   0.003716  0.550041  0.023010  0.027190    47.481210     26.089900
# 구리시   0.003237  0.400459  0.026097  0.023649    45.113665     25.718412
# 군포시   0.003793  0.465993  0.028549  0.026254    50.490362     25.043334
# 김포시   0.003468  0.389926  0.031709  0.016176    46.798101     26.200935
# 남양주시  0.003019  0.486573  0.026645  0.021940    43.084163     24.879299
# 동두천시  0.003929  0.401154  0.030808  0.015464    43.247049     25.369355
# 부천시   0.004965  0.529346  0.024800  0.029254    54.752938     32.670581
# 성남시   0.003342  0.618114  0.023654  0.032784    43.395162     23.683875
# 수원시   0.003274  0.616823  0.025057  0.029663    43.788240     24.656669
# ...

# %%
df_last.loc[['의정부시']]
# Out:
#       아황산가스농도값  일산화탄소농도값     오존농도값  이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값  \
# 시군명
# 의정부시  0.003711  0.570571  0.028368  0.024719    42.848992     23.217915
#
#       전체온실가스배출량
# 시군명
# 의정부시      88388

# %%
df_last.columns
# Out:
# Index(['아황산가스농도값', '일산화탄소농도값', '오존농도값', '이산화질소농도값', '미세먼지PM10농도값',
#        '미세먼지PM2.5농도값', '전체온실가스배출량'],
#       dtype='object')

# %%
df_last.index
# Out:
# Index(['고양시', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시', '남양주시', '동두천시', '부천시',
#        '성남시', '수원시', '시흥시', '안산시', '안성시', '안양시', '양주시', '여주시', '오산시', '용인시',
#        '의정부시', '이천시', '파주시', '평택시', '포천시', '하남시', '화성시'],
#       dtype='object', name='시군명')

# %%
df_last.to_csv('df2.csv')

# %%
df_last.columns[1:]
# Out:
# Index(['아황산가스농도값', '일산화탄소농도값', '오존농도값', '이산화질소농도값', '미세먼지PM10농도값',
#        '미세먼지PM2.5농도값', '전체온실가스배출량'],
#       dtype='object')

# %%
df_last
# Out:
#      시군명  아황산가스농도값  일산화탄소농도값     오존농도값  이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값  \
# 0    고양시  0.003617  0.479440  0.028511  0.022422    46.249278     25.890895
# 1    과천시  0.003458  0.604482  0.024121  0.027413    44.496612     21.773890
# 2    광명시  0.003335  0.539361  0.027107  0.032184    48.194850     25.228596
# 3    광주시  0.003716  0.550041  0.023010  0.027190    47.481210     26.089900
# 4    구리시  0.003237  0.400459  0.026097  0.023649    45.113665     25.718412
# 5    군포시  0.003793  0.465993  0.028549  0.026254    50.490362     25.043334
# 6    김포시  0.003468  0.389926  0.031709  0.016176    46.798101     26.200935
# 7   남양주시  0.003019  0.486573  0.026645  0.021940    43.084163     24.879299
# 8   동두천시  0.003929  0.401154  0.030808  0.015464    43.247049     25.369355
# 9    부천시  0.004965  0.529346  0.024800  0.029254    54.752938     32.670581
# 10   성남시  0.003342  0.618114  0.023654  0.032784    43.395162     23.683875
# ...

# %%
df_last['시군명'] == '고양시'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# Name: 시군명, dtype: bool

# %%
df_last.loc[df_last['시군명'] == '고양시', ]
# Out:
#    시군명  아황산가스농도값  일산화탄소농도값     오존농도값  이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값  \
# 0  고양시  0.003617   0.47944  0.028511  0.022422    46.249278     25.890895
#
#    전체온실가스배출량
# 0     247921

# %%
list(df_last['시군명'])
# Out:
# ['고양시',
#  '과천시',
#  '광명시',
#  '광주시',
#  '구리시',
#  '군포시',
#  '김포시',
#  '남양주시',
#  '동두천시',
#  '부천시',
#  '성남시',
#  '수원시',
#  '시흥시',
#  '안산시',
#  '안성시',
#  '안양시',
#  '양주시',
#  '여주시',
#  '오산시',
#  '용인시',
#  '의정부시',
#  '이천시',
#  '파주시',
#  '평택시',
#  '포천시',
#  '하남시',
#  '화성시']

# %%
# %matplotlib inline

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
# 프로펫으로 학습

# %%
df
# Out:
#          시군코드  시군명      측정소명    설치년도   측정망명             측정일시각  아황산가스농도값  \
# 0       41820  가평군        가평  2010.0   도시대기  2019-12-31 24:00     0.004
# 1       41280  고양시  백마로(마두역)  2004.0  도로변대기  2019-12-31 24:00     0.003
# 2       41280  고양시       식사동  2002.0   도시대기  2019-12-31 24:00     0.003
# 3       41280  고양시       신원동  2016.0   도시대기  2019-12-31 24:00     0.007
# 4       41280  고양시       주엽동  2018.0   도시대기  2019-12-31 24:00     0.003
# ...       ...  ...       ...     ...    ...               ...       ...
# 815428  41590  화성시       남양읍     NaN   도시대기  2019-01-01 01:00     0.003
# 815429  41590  화성시        동탄     NaN   도시대기  2019-01-01 01:00     0.003
# 815430  41590  화성시       우정읍     NaN   도시대기  2019-01-01 01:00     0.002
# 815431  41590  화성시       청계동  2018.0   도시대기  2019-01-01 01:00     0.004
# 815432  41590  화성시       향남읍     NaN   도시대기  2019-01-01 01:00     0.003
#
#         일산화탄소농도값  오존농도값  이산화질소농도값  미세먼지PM10농도값  미세먼지PM2.5농도값
# ...

# %%
df = df.loc[ : ,['측정일시각', '시군명', '아황산가스농도값', '일산화탄소농도값', '오존농도값',
            '이산화질소농도값', '미세먼지PM10농도값', '미세먼지PM2.5농도값']]

# %%
df
# Out:
#                    측정일시각  시군명  아황산가스농도값  일산화탄소농도값  오존농도값  이산화질소농도값  \
# 0       2019-12-31 24:00  가평군     0.004       0.5  0.024     0.009
# 1       2019-12-31 24:00  고양시     0.003       0.6  0.007     0.037
# 2       2019-12-31 24:00  고양시     0.003       0.4  0.004     0.019
# 3       2019-12-31 24:00  고양시     0.007       0.5  0.008     0.028
# 4       2019-12-31 24:00  고양시     0.003       0.5  0.012     0.027
# ...                  ...  ...       ...       ...    ...       ...
# 815428  2019-01-01 01:00  화성시     0.003       0.4  0.026     0.013
# 815429  2019-01-01 01:00  화성시     0.003       0.5  0.002     0.032
# 815430  2019-01-01 01:00  화성시     0.002       0.4  0.026     0.006
# 815431  2019-01-01 01:00  화성시     0.004       0.6  0.002     0.036
# 815432  2019-01-01 01:00  화성시     0.003       0.5  0.020     0.018
#
#         미세먼지PM10농도값  미세먼지PM2.5농도값
# 0              22.0          11.0
# 1              35.0          12.0
# 2              26.0           9.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815433 entries, 0 to 815432
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   측정일시각         815433 non-null  object
#  1   시군명           815433 non-null  object
#  2   아황산가스농도값      785899 non-null  float64
#  3   일산화탄소농도값      787727 non-null  float64
#  4   오존농도값         772765 non-null  float64
#  5   이산화질소농도값      796643 non-null  float64
#  6   미세먼지PM10농도값   791849 non-null  float64
#  7   미세먼지PM2.5농도값  764063 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 49.8+ MB

# %%
df['측정일시각']
# Out:
# 0         2019-12-31 24:00
# 1         2019-12-31 24:00
# 2         2019-12-31 24:00
# 3         2019-12-31 24:00
# 4         2019-12-31 24:00
#                 ...
# 815428    2019-01-01 01:00
# 815429    2019-01-01 01:00
# 815430    2019-01-01 01:00
# 815431    2019-01-01 01:00
# 815432    2019-01-01 01:00
# Name: 측정일시각, Length: 815433, dtype: object

# %%
df['측정일시각'][0][:10]
# Out:
# '2019-12-31'

# %%
range(len(df['측정일시각'].values))
# Out:
# range(0, 815433)

# %%
new_list = []
for i in range(len(df['측정일시각'].values)) :
    data = df['측정일시각'][i][:10]
    new_list.append(data)

# %%
df['측정시각'] = new_list

# %%
df
# Out:
#                    측정일시각  시군명  아황산가스농도값  일산화탄소농도값  오존농도값  이산화질소농도값  \
# 0       2019-12-31 24:00  가평군     0.004       0.5  0.024     0.009
# 1       2019-12-31 24:00  고양시     0.003       0.6  0.007     0.037
# 2       2019-12-31 24:00  고양시     0.003       0.4  0.004     0.019
# 3       2019-12-31 24:00  고양시     0.007       0.5  0.008     0.028
# 4       2019-12-31 24:00  고양시     0.003       0.5  0.012     0.027
# ...                  ...  ...       ...       ...    ...       ...
# 815428  2019-01-01 01:00  화성시     0.003       0.4  0.026     0.013
# 815429  2019-01-01 01:00  화성시     0.003       0.5  0.002     0.032
# 815430  2019-01-01 01:00  화성시     0.002       0.4  0.026     0.006
# 815431  2019-01-01 01:00  화성시     0.004       0.6  0.002     0.036
# 815432  2019-01-01 01:00  화성시     0.003       0.5  0.020     0.018
#
#         미세먼지PM10농도값  미세먼지PM2.5농도값        측정시각
# 0              22.0          11.0  2019-12-31
# 1              35.0          12.0  2019-12-31
# ...

# %%
df = df.loc[ : ,['측정시각', '시군명', '아황산가스농도값', '일산화탄소농도값', '오존농도값',
            '이산화질소농도값', '미세먼지PM10농도값', '미세먼지PM2.5농도값']]

# %%
df
# Out:
#               측정시각  시군명  아황산가스농도값  일산화탄소농도값  오존농도값  이산화질소농도값  미세먼지PM10농도값  \
# 0       2019-12-31  가평군     0.004       0.5  0.024     0.009         22.0
# 1       2019-12-31  고양시     0.003       0.6  0.007     0.037         35.0
# 2       2019-12-31  고양시     0.003       0.4  0.004     0.019         26.0
# 3       2019-12-31  고양시     0.007       0.5  0.008     0.028         33.0
# 4       2019-12-31  고양시     0.003       0.5  0.012     0.027         25.0
# ...            ...  ...       ...       ...    ...       ...          ...
# 815428  2019-01-01  화성시     0.003       0.4  0.026     0.013         26.0
# 815429  2019-01-01  화성시     0.003       0.5  0.002     0.032         32.0
# 815430  2019-01-01  화성시     0.002       0.4  0.026     0.006         41.0
# 815431  2019-01-01  화성시     0.004       0.6  0.002     0.036         35.0
# 815432  2019-01-01  화성시     0.003       0.5  0.020     0.018         49.0
#
#         미세먼지PM2.5농도값
# 0               11.0
# 1               12.0
# ...

# %%
df['측정시각'] = pd.to_datetime(df['측정시각'], infer_datetime_format=True)
# (df['측정일시각'], format= '%Y-%m-%d %I:%M' )
# pd.to_datetime(chicago_df['Date'], format= '%m/%d/%Y %I:%M:%S %p' )

# %%
df
# Out:
#              측정시각  시군명  아황산가스농도값  일산화탄소농도값  오존농도값  이산화질소농도값  미세먼지PM10농도값  \
# 0      2019-12-31  가평군     0.004       0.5  0.024     0.009         22.0
# 1      2019-12-31  고양시     0.003       0.6  0.007     0.037         35.0
# 2      2019-12-31  고양시     0.003       0.4  0.004     0.019         26.0
# 3      2019-12-31  고양시     0.007       0.5  0.008     0.028         33.0
# 4      2019-12-31  고양시     0.003       0.5  0.012     0.027         25.0
# ...           ...  ...       ...       ...    ...       ...          ...
# 815428 2019-01-01  화성시     0.003       0.4  0.026     0.013         26.0
# 815429 2019-01-01  화성시     0.003       0.5  0.002     0.032         32.0
# 815430 2019-01-01  화성시     0.002       0.4  0.026     0.006         41.0
# 815431 2019-01-01  화성시     0.004       0.6  0.002     0.036         35.0
# 815432 2019-01-01  화성시     0.003       0.5  0.020     0.018         49.0
#
#         미세먼지PM2.5농도값
# 0               11.0
# 1               12.0
# 2                9.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815433 entries, 0 to 815432
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   측정시각          815433 non-null  datetime64[ns]
#  1   시군명           815433 non-null  object
#  2   아황산가스농도값      785899 non-null  float64
#  3   일산화탄소농도값      787727 non-null  float64
#  4   오존농도값         772765 non-null  float64
#  5   이산화질소농도값      796643 non-null  float64
#  6   미세먼지PM10농도값   791849 non-null  float64
#  7   미세먼지PM2.5농도값  764063 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 49.8+ MB

# %%
df.sort_values('측정시각', inplace= True)

# %%
df
# Out:
#              측정시각  시군명  아황산가스농도값  일산화탄소농도값  오존농도값  이산화질소농도값  미세먼지PM10농도값  \
# 815432 2019-01-01  화성시     0.003       0.5  0.020     0.018         49.0
# 813980 2019-01-01  평택시     0.004       0.4  0.017     0.019         48.0
# 813981 2019-01-01  평택시     0.004       0.5  0.032     0.010         40.0
# 813982 2019-01-01  평택시     0.004       0.2  0.037     0.007         48.0
# 813983 2019-01-01  평택시     0.004       0.4  0.034     0.009         40.0
# ...           ...  ...       ...       ...    ...       ...          ...
# 1518   2019-12-31  화성시     0.006       0.4  0.014     0.022         20.0
# 1517   2019-12-31  화성시     0.002       0.4  0.032     0.007         12.0
# 1516   2019-12-31  화성시     0.004       0.4  0.017     0.014         33.0
# 1522   2019-12-31  고양시     0.002       0.3  0.031     0.006         21.0
# 0      2019-12-31  가평군     0.004       0.5  0.024     0.009         22.0
#
#         미세먼지PM2.5농도값
# 815432          34.0
# 813980          26.0
# 813981          29.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['측정시각'], df['미세먼지PM10농도값'])

# %%
df_pm10 = df.groupby('측정시각')['미세먼지PM10농도값'].mean()

# %%
df_pm10.plot()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
df_pm2_5 = df.groupby('측정시각')['미세먼지PM2.5농도값'].mean()

# %%
df_pm2_5.plot()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52769 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
df.head(3)
# Out:
#              측정시각  시군명  아황산가스농도값  일산화탄소농도값  오존농도값  이산화질소농도값  미세먼지PM10농도값  \
# 815432 2019-01-01  화성시     0.003       0.5  0.020     0.018         49.0
# 813980 2019-01-01  평택시     0.004       0.4  0.017     0.019         48.0
# 813981 2019-01-01  평택시     0.004       0.5  0.032     0.010         40.0
#
#         미세먼지PM2.5농도값
# 815432          34.0
# 813980          26.0
# 813981          29.0

# %%
finedusk_prophet_df = df[['측정시각', '미세먼지PM10농도값']]

# %%
finedusk_prophet_df
# Out:
#              측정시각  미세먼지PM10농도값
# 815432 2019-01-01         49.0
# 813980 2019-01-01         48.0
# 813981 2019-01-01         40.0
# 813982 2019-01-01         48.0
# 813983 2019-01-01         40.0
# ...           ...          ...
# 1518   2019-12-31         20.0
# 1517   2019-12-31         12.0
# 1516   2019-12-31         33.0
# 1522   2019-12-31         21.0
# 0      2019-12-31         22.0
#
# [815433 rows x 2 columns]

# %%
finedusk_prophet_df.columns = ['ds', 'y']

# %%
finedusk_prophet_df.head(3)
# Out:
#                ds     y
# 815432 2019-01-01  49.0
# 813980 2019-01-01  48.0
# 813981 2019-01-01  40.0

# %%
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1252/1130067940.py in <module>
# ----> 1 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'
