# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import urllib.request
import os
import pandas as pd

# %%
url_dict = {}
df_corr = pd.read_csv('df_corr.csv', index_col=0)

# %%
for i in range(len(df_corr.columns)) :

    chrome_path ='C:\\Users\\-\\Documents\\GitHub\\yh_seo\\project\\movie\\croll\chromedriver.exe'
    base_url = "https://www.google.co.kr/imghp"

    chrome_options = webdriver.ChromeOptions()
    # chrome_options.add_argument('--headless') # 창 없는 모드
    # headless 모드의 호환성을 위해 아래 옵션 추가(가끔 막는 웹이 있음)
    #chrome_options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")
    chrome_options.add_argument("lang=ko_KR") # 한국어
    chrome_options.add_argument('window-size=1920x1080')
    # chrome_options.add_argument('--no-sandbox')
    # chrome_options.add_argument('--disable-dev-shm-usage')


    driver = webdriver.Chrome(chrome_path,chrome_options=chrome_options)
    driver.get(base_url)
    driver.implicitly_wait(3) # element가 로드될 때까지 지정한 시간만큼 대기할 수 있도록 설정
    driver.get_screenshot_as_file('google_screen.png')
    driver.close()

#     def selenium_scroll_option():
#         SCROLL_PAUSE_SEC = 3

#         # 스크롤 높이 가져옴
#         last_height = driver.execute_script("return document.body.scrollHeight")

#         while True:
#             # 끝까지 스크롤 다운
#             driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

#             # 1초 대기
#             time.sleep(SCROLL_PAUSE_SEC)

#             # 스크롤 다운 후 스크롤 높이 다시 가져옴
#             new_height = driver.execute_script("return document.body.scrollHeight")

#             if new_height == last_height:
#                 break
#             last_height = new_height

    choice_movie = df_corr.columns[i]

    a= 'movie ' + choice_movie
    image_name = 'amugona'
    #b=int(input("몇 개 저장할래? : "))
    driver = webdriver.Chrome(chrome_path)
    driver.get('http://www.google.co.kr/imghp?hl=ko')
    browser = driver.find_element_by_name("q")
    browser.send_keys(a)
    browser.send_keys(Keys.RETURN)

    images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd") #  클래스 네임에서 공백은 .을 찍어줌
    images_url = []
    for i in images: 

        if i.get_attribute('src')!= None :
                images_url.append(i.get_attribute('src'))
        else :
            images_url.append(i.get_attribute('data-src'))
    driver.close()

    img = images_url[0]
#     print(img)
    url_dict[choice_movie] = img
# Out:
# C:\Users\-\AppData\Local\Temp/ipykernel_1776/987020877.py:16: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path,chrome_options=chrome_options)
# C:\Users\-\AppData\Local\Temp/ipykernel_1776/987020877.py:16: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_path,chrome_options=chrome_options)
# C:\Users\-\AppData\Local\Temp/ipykernel_1776/987020877.py:47: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# C:\Users\-\AppData\Local\Temp/ipykernel_1776/987020877.py:49: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   browser = driver.find_element_by_name("q")
# C:\Users\-\AppData\Local\Temp/ipykernel_1776/987020877.py:53: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd") #  클래스 네임에서 공백은 .을 찍어줌
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1776/987020877.py in <module>
#      61     driver.close()
#      62
# ---> 63     img = images_url[0]
#      64 #     print(img)
#      65     url_dict[choice_movie] = img
#
# IndexError: list index out of range

# %%
url_dict
# Out:
# {'28 Days Later': 'data:image/jpeg;base64,...',
#  '300': 'data:image/jpeg;base64,...',
#  '7 Virgins': 'data:image/jpeg;base64,...',
#  '8 Women': 'data:image/jpeg;base64,...',
#  '88 Minutes': 'data:image/jpeg;base64,...',
#  'A Bridge Too Far': 'data:image/jpeg;base64,...',
#  'A Close Shave': 'data:image/jpeg;base64,...',
#  'A Kiss Before Dying': 'data:image/jpeg;base64,...',
#  'A Perfect Murder': 'data:image/jpeg;base64,...',
#  'A Tale of Two Cities': 'data:image/jpeg;base64,...',
#  'A Woman, a Gun and a Noodle Shop': 'data:image/jpeg;base64,...',
#  'Addicted to Love': 'data:image/jpeg;base64,...',
#  'Adventures of Zatôichi': 'data:image/jpeg;base64,...',
#  'Ali: Fear Eats the Soul': 'data:image/jpeg;base64,...',
#  'Alien': 'data:image/jpeg;base64,...',
#  'American Beauty': 'data:image/jpeg;base64,...',
#  'American Graffiti': 'data:image/jpeg;base64,...',
#  'American Pie 2': 'data:image/jpeg;base64,...',
#  'Amigo, Stay Away': 'data:image/jpeg;base64,...',
#  'Amélie': 'data:image/jpeg;base64,...',
#  'An Unfinished Life': 'data:image/jpeg;base64,...',
#  'Annaluise & Anton': 'data:image/jpeg;base64,...',
#  "Anybody's Son Will Do": '...',
#  'Ask the Dust': 'data:image/jpeg;base64,...',
#  'Back to the Future': 'data:image/jpeg;base64,...',
#  'Bad Education': 'data:image/jpeg;base64,...',
#  'Batman Begins': 'data:image/jpeg;base64,...',
#  'Beat': 'data:image/jpeg;base64,...',
#  'Because I Said So': 'data:image/jpeg;base64,...',
#  'Ben X': 'data:image/jpeg;base64,...',
#  'Berlin: Symphony of a Great City': 'data:image/jpeg;base64,...',
#  'Best Worst Movie': 'data:image/jpeg;base64,...',
#  'Beverly Hills Cop III': 'data:image/jpeg;base64,...',
#  'Big Bad Mama': 'data:image/jpeg;base64,...',
#  "Big Girls Don't Cry... They Get Even": 'data:image/jpeg;base64,...',
#  'Birdman of Alcatraz': 'data:image/jpeg;base64,...',
#  'Black Rain': 'data:image/jpeg;base64,...',
#  'Bonnie and Clyde': 'data:image/jpeg;base64,...',
#  'Brake': 'data:image/jpeg;base64,...',
#  'Breaking and Entering': 'data:image/jpeg;base64,...',
#  'Broken Flowers': 'data:image/jpeg;base64,...',
#  'Brothers': 'data:image/jpeg;base64,...',
#  'Bullitt': 'data:image/jpeg;base64,...',
#  'Caesar Must Die': 'data:image/jpeg;base64,...',
#  'Carry On Doctor': 'data:image/jpeg;base64,...',
#  'Casino': 'data:image/jpeg;base64,...',
#  'Cat on a Hot Tin Roof': 'data:image/jpeg;base64,...',
#  'Clean, Shaven': 'data:image/jpeg;base64,...',
#  'Cleopatra Jones and the Casino of Gold': 'data:image/jpeg;base64,...',
#  'Closer': 'data:image/jpeg;base64,...',
#  'Cold Mountain': 'data:image/jpeg;base64,...',
#  'Color of Night': 'data:image/jpeg;base64,...',
#  'Cube': 'data:image/jpeg;base64,...',
#  'Dead Man': 'data:image/jpeg;base64,...',
#  'Dead Poets Society': 'data:image/jpeg;base64,...',
#  'Destroy All Monsters': 'data:image/jpeg;base64,...',
#  'Die Hard': 'data:image/jpeg;base64,...',
#  'Dirty Dancing': 'data:image/jpeg;base64,...',
#  'Disclosure': 'data:image/jpeg;base64,...',
#  'Dog Day Afternoon': 'data:image/jpeg;base64,...',
#  'Dollman vs. Demonic Toys': 'data:image/jpeg;base64,...',
#  'Don Q Son of Zorro': 'data:image/jpeg;base64,...',
#  "Don't Worry, I'm Fine": 'data:image/jpeg;base64,...',
#  'Downhill Racer': 'data:image/jpeg;base64,...',
#  'Dr. Jekyll and Mr. Hyde': 'data:image/jpeg;base64,...',
#  'Dreamgirls': 'data:image/jpeg;base64,...',
#  'EVA': 'data:image/jpeg;base64,...',
#  'Edward Scissorhands': 'data:image/jpeg;base64,...',
#  'Edward, My Son': 'data:image/jpeg;base64,...',
#  'Eight Miles High': 'data:image/jpeg;base64,...',
#  'Elevator to the Gallows': 'data:image/jpeg;base64,...',
#  'Enough': 'data:image/jpeg;base64,...',
#  'Escape from New York': 'data:image/jpeg;base64,...',
#  'Escape from the Planet of the Apes': 'data:image/jpeg;base64,...',
#  'Evil Dead II': 'data:image/jpeg;base64,...',
#  'Eyes Wide Shut': 'data:image/jpeg;base64,...',
#  'Farewell, My Lovely': 'data:image/jpeg;base64,...',
#  'Final Fantasy VII: Advent Children': 'data:image/jpeg;base64,...',
#  'Finding Neverland': 'data:image/jpeg;base64,...',
#  'Flags of Our Fathers': 'data:image/jpeg;base64,...',
#  'Flashdance': 'data:image/jpeg;base64,...',
#  'Forbidden Planet': 'data:image/jpeg;base64,...',
#  'Frances': 'data:image/jpeg;base64,...',
#  'Frankenstein Created Woman': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSvZixFxMA_AM4tNr_V1vBqUMUY2Wdcax0h5ox_Ox48rHjEKt0D5C9EbXCXOC3I7wRDTyM&usqp=CAU',
#  'Frankenstein Unbound': 'data:image/jpeg;base64,...',
#  'Galaxy Quest': 'data:image/jpeg;base64,...',
#  'Ghost Dog: The Way of the Samurai': 'data:image/jpeg;base64,...',
#  'Godzilla': 'data:image/jpeg;base64,...',
#  'Gravity': 'data:image/jpeg;base64,...',
#  'Gremlins 2: The New Batch': 'data:image/jpeg;base64,...',
#  'Guter Junge': 'data:image/jpeg;base64,...',
#  'Halloween': 'data:image/jpeg;base64,...',
#  'Hannibal Rising': 'data:image/jpeg;base64,...',
#  "Harry Potter and the Philosopher's Stone": 'data:image/jpeg;base64,...',
#  'Heart of the Country': 'data:image/jpeg;base64,...',
#  'Hero': 'data:image/jpeg;base64,...',
#  'Hitman': 'data:image/jpeg;base64,...',
#  'Hollywoodland': 'data:image/jpeg;base64,...',
#  'Horrible Bosses': 'data:image/jpeg;base64,...',
#  'Hotel Very Welcome': 'data:image/jpeg;base64,...',
#  'Hour of the Gun': 'data:image/jpeg;base64,...',
#  'House of 1000 Corpses': 'data:image/jpeg;base64,...',
#  'House of Dracula': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRamjqxP0E9TlIcB5Ktc7ahjv1yhP4XDdqFHQSTig3gwNzvK4iSQHiwNnOgKHlU8Pr5glc&usqp=CAU',
#  'Human Nature': 'data:image/jpeg;base64,...',
#  'In Time': 'data:image/jpeg;base64,...',
#  'Jack & Sarah': 'data:image/jpeg;base64,...',
#  'James Dean': 'data:image/jpeg;base64,...',
#  'Joshua': 'data:image/jpeg;base64,...',
#  'Ken Park': 'data:image/jpeg;base64,...',
#  'Kill Bill: Vol. 1': 'data:image/jpeg;base64,...',
#  'Killer': 'data:image/jpeg;base64,...',
#  'King Kong vs. Godzilla': 'data:image/jpeg;base64,...',
#  'Kiss of the Dragon': 'data:image/jpeg;base64,...',
#  'Los Olvidados': 'data:image/jpeg;base64,...',
#  'Love Is the Devil: Study for a Portrait of Francis Bacon': 'data:image/jpeg;base64,...',
#  'Mad Dog Coll': 'data:image/jpeg;base64,...',
#  'Madame Bovary': 'data:image/jpeg;base64,...',
#  'Mala Noche': 'data:image/jpeg;base64,...',
#  'Malcolm X': 'data:image/jpeg;base64,...',
#  'Man of Marble': 'data:image/jpeg;base64,...',
#  'Mean Streets': 'data:image/jpeg;base64,...',
#  'Meet Me in St. Louis': 'data:image/jpeg;base64,...',
#  'Meet the Robinsons': 'data:image/jpeg;base64,...',
#  'Memoirs of an Invisible Man': 'data:image/jpeg;base64,...',
#  'Metamorphosis': 'data:image/jpeg;base64,...',
#  'Minority Report': 'data:image/jpeg;base64,...',
#  'Mission to Mars': 'data:image/jpeg;base64,...',
#  'Mission: Impossible': 'data:image/jpeg;base64,...',
#  'Modern Times': 'data:image/jpeg;base64,...',
#  'Mr. Smith Goes to Washington': 'data:image/jpeg;base64,...',
#  'My Own Private Idaho': 'data:image/jpeg;base64,...',
#  'My Sweet Little Village': 'data:image/jpeg;base64,...',
#  'My Tutor': 'data:image/jpeg;base64,...',
#  'Nell': 'data:image/jpeg;base64,...',
#  'New York Doll': 'data:image/jpeg;base64,...',
#  'No Reservations': 'data:image/jpeg;base64,...',
#  'Notorious': 'data:image/jpeg;base64,...',
#  "Olga's House of Shame": 'data:image/jpeg;base64,...',
#  'Once in a Lifetime: The Extraordinary Story of the New York Cosmos': 'data:image/jpeg;base64,...',
#  "One Night at McCool's": 'data:image/jpeg;base64,...',
#  'Or (My Treasure)': 'data:image/jpeg;base64,...',
#  'Out of Time': 'data:image/jpeg;base64,...',
#  'Pirates of the Caribbean: The Curse of the Black Pearl': 'data:image/jpeg;base64,...',
#  'Postal': 'data:image/jpeg;base64,...',
#  'Prime': 'data:image/jpeg;base64,...',
#  'Read It and Weep': 'data:image/jpeg;base64,...',
#  'Reality Bites': 'data:image/jpeg;base64,...',
#  'Reclaim Your Brain': 'data:image/jpeg;base64,...',
#  'Return of the Jedi': 'data:image/jpeg;base64,...',
#  'Revolutionary Road': 'data:image/jpeg;base64,...',
#  'Righteous Ties': 'data:image/jpeg;base64,...',
#  'Rocky II': 'data:image/jpeg;base64,...',
#  'Rocky III': 'data:image/jpeg;base64,...',
#  'Rome, Open City': 'data:image/jpeg;base64,...',
#  'Romeo Must Die': 'data:image/jpeg;base64,...',
#  'Roustabout': 'data:image/jpeg;base64,...',
#  'Rumble Fish': 'data:image/jpeg;base64,...',
#  'Rush Hour': 'data:image/jpeg;base64,...',
#  'Saw II': 'data:image/jpeg;base64,...',
#  'Secret Agent': 'data:image/jpeg;base64,...',
#  'Shiloh': 'data:image/jpeg;base64,...',
#  'Short Circuit': 'data:image/jpeg;base64,...',
#  'Shortbus': 'data:image/jpeg;base64,...',
#  'Sicko': 'data:image/jpeg;base64,...',
#  'Snatch': 'data:image/jpeg;base64,...',
#  'Sommersby': 'data:image/jpeg;base64,...',
#  'Soul Assassin': 'data:image/jpeg;base64,...',
#  'Space Jam': 'data:image/jpeg;base64,...',
#  'Spanglish': 'data:image/jpeg;base64,...',
#  'Straw Dogs': 'data:image/jpeg;base64,...',
#  'Stuck on You': 'data:image/jpeg;base64,...',
#  "Summer '04": 'data:image/jpeg;base64,...',
#  'Sunshine': 'data:image/jpeg;base64,...',
#  'Sweet November': 'data:image/jpeg;base64,...',
#  'Swept from the Sea': 'data:image/jpeg;base64,...',
#  "Teheran '43": 'data:image/jpeg;base64,...',
#  'Terminator 2: Judgment Day': 'data:image/jpeg;base64,...',
#  'Terminator Salvation': 'data:image/jpeg;base64,...',
#  'That Most Important Thing: Love': 'data:image/jpeg;base64,...',
#  'The Bachelor': 'data:image/jpeg;base64,...',
#  'The Beach': 'data:image/jpeg;base64,...',
#  'The Big Blue': 'data:image/jpeg;base64,...',
#  'The Big Parade': 'data:image/jpeg;base64,...',
#  'The Bourne Identity': 'data:image/jpeg;base64,...',
#  'The Boys from County Clare': 'data:image/jpeg;base64,...',
#  'The Breakfast Club': 'data:image/jpeg;base64,...',
#  'The Bridge': 'data:image/jpeg;base64,...',
#  'The Chorus': 'data:image/jpeg;base64,...',
#  'The Coast Guard': 'data:image/jpeg;base64,...',
#  'The Contract': 'data:image/jpeg;base64,...',
#  'The Crazy Family': 'data:image/jpeg;base64,...',
#  'The Dawn Patrol': 'data:image/jpeg;base64,...',
#  'The Diving Bell and the Butterfly': 'data:image/jpeg;base64,...',
#  'The Elephant Man': 'data:image/jpeg;base64,...',
#  'The Ewok Adventure': 'data:image/jpeg;base64,...',
#  'The Fifth Element': 'data:image/jpeg;base64,...',
#  'The Getaway': 'data:image/jpeg;base64,...',
#  'The Gift': 'data:image/jpeg;base64,...',
#  'The Great Dictator': 'data:image/jpeg;base64,...',
#  'The Hunchback of Notre Dame': 'data:image/jpeg;base64,...',
#  'The Island': 'data:image/jpeg;base64,...',
#  'The Killing': 'data:image/jpeg;base64,...',
#  'The Last Laugh': 'data:image/jpeg;base64,...',
#  'The Last Mistress': 'data:image/jpeg;base64,...',
#  'The Last Samurai': 'data:image/jpeg;base64,...',
#  'The Legend of Paul and Paula': 'data:image/jpeg;base64,...',
#  'The Mikado': 'data:image/jpeg;base64,...',
#  'The Most Dangerous Game': 'data:image/jpeg;base64,...',
#  'The Mourning Forest': 'data:image/jpeg;base64,...',
#  'The Mystery of Chess Boxing': 'data:image/jpeg;base64,...',
#  'The Night Child': 'data:image/jpeg;base64,...',
#  'The Nomi Song': 'data:image/jpeg;base64,...',
#  'The Orphanage': 'data:image/jpeg;base64,...',
#  'The Out-of-Towners': 'data:image/jpeg;base64,...',
#  'The Pawnshop': 'data:image/jpeg;base64,...',
#  'The Perfect Storm': 'data:image/jpeg;base64,...',
#  'The Prestige': 'data:image/jpeg;base64,...',
#  'The Projected Man': 'data:image/jpeg;base64,...',
#  'The Rapture': 'data:image/jpeg;base64,...',
#  'The Redeemer: Son of Satan!': 'data:image/jpeg;base64,...',
#  'The Remains of the Day': 'data:image/jpeg;base64,...',
#  'The Sicilian Clan': 'data:image/jpeg;base64,...',
#  'The Time Machine': 'data:image/jpeg;base64,...',
#  'The Vexxer': 'data:image/jpeg;base64,...',
#  'The Village': 'data:image/jpeg;base64,...',
#  'The War of the Roses': 'data:image/jpeg;base64,...',
#  'The Way of the Gun': 'data:image/jpeg;base64,...',
#  'The Wedding Planner': 'data:image/jpeg;base64,...',
#  'The White Sound': 'data:image/jpeg;base64,...',
#  'The Woman with the 5 Elephants': 'data:image/jpeg;base64,...',
#  'The Wrong Trousers': 'data:image/jpeg;base64,...',
#  'The Yes Men': 'data:image/jpeg;base64,...',
#  'This Is 40': 'data:image/jpeg;base64,...',
#  'Three-Step Dance': 'data:image/jpeg;base64,...',
#  'To Be or Not to Be': 'data:image/jpeg;base64,...',
#  'To Catch a Thief': 'data:image/jpeg;base64,...',
#  'Top of the Food Chain': 'data:image/jpeg;base64,...',
#  'Torrente 2: Mission in Marbella': 'data:image/jpeg;base64,...',
#  'Torrente, the Dumb Arm of the Law': 'data:image/jpeg;base64,...',
#  'True Romance': 'data:image/jpeg;base64,...',
#  "Tuya's Marriage": 'data:image/jpeg;base64,...',
#  'Underworld': 'data:image/jpeg;base64,...',
#  'Van Gogh': 'data:image/jpeg;base64,...',
#  'Videodrome': 'data:image/jpeg;base64,...',
#  'Voyage to the Bottom of the Sea': 'data:image/jpeg;base64,...',
#  'Walk the Line': 'data:image/jpeg;base64,...',
#  "We're No Angels": 'data:image/jpeg;base64,...',
#  'Wedlock': 'data:image/jpeg;base64,...',
#  "What's Eating Gilbert Grape": 'data:image/jpeg;base64,...',
#  "What's New Pussycat?": 'data:image/jpeg;base64,...',
#  'While You Were Sleeping': 'data:image/jpeg;base64,...',
#  'Willy Wonka & the Chocolate Factory': 'data:image/jpeg;base64,...',
#  'Wish You Were Here': 'data:image/jpeg;base64,...',
#  'Within the Woods': 'data:image/jpeg;base64,...',
#  'Yankee Doodle Dandy': 'data:image/jpeg;base64,...',
#  'Young Adam': 'data:image/jpeg;base64,...',
#  'Young Frankenstein': 'data:image/jpeg;base64,...',
#  'Zatoichi': 'data:image/jpeg;base64,...'}

# %%
url_dict['300']
# Out:
# 'data:image/jpeg;base64,...'

# %%
df_pivot = pd.read_csv('df_pivot.csv', index_col=0)

# %%
df_pivot
# Out:
#      10 Items or Less  2 Days in Paris  20,000 Leagues Under the Sea  \
# 0                 NaN              NaN                           NaN
# 1                 NaN              NaN                           NaN
# 2                 NaN              NaN                           NaN
# 3                 NaN              NaN                           3.0
# 4                 NaN              NaN                           NaN
# ..                ...              ...                           ...
# 669               NaN              NaN                           NaN
# 670               NaN              NaN                           NaN
# 671               3.0              NaN                           NaN
# 672               NaN              NaN                           3.0
# 673               NaN              NaN                           3.0
#
#      2001: A Space Odyssey  24 Hour Party People  25th Hour  28 Days Later  \
# 0                      NaN                   NaN        NaN            NaN
# 1                      3.0                   NaN        NaN            NaN
# 2                      NaN                   NaN        NaN            NaN
# 3                      NaN                   NaN        NaN            NaN
# 4                      NaN                   NaN        NaN            NaN
# ..                     ...                   ...        ...            ...
# 669                    NaN                   NaN        NaN            NaN
# 670                    NaN                   NaN        NaN            NaN
# 671                    NaN                   NaN        NaN            NaN
# 672                    NaN                   NaN        NaN            NaN
# 673                    NaN                   NaN        NaN            NaN
#
#      28 Weeks Later  3-Iron  300  ...  Yella  Yesterday  Young Adam  \
# 0               NaN     NaN  NaN  ...    NaN        NaN         NaN
# 1               NaN     NaN  NaN  ...    NaN        NaN         NaN
# 2               NaN     NaN  3.0  ...    NaN        NaN         NaN
# 3               NaN     NaN  NaN  ...    NaN        NaN         NaN
# 4               NaN     NaN  NaN  ...    NaN        NaN         NaN
# ..              ...     ...  ...  ...    ...        ...         ...
# 669             NaN     NaN  NaN  ...    NaN        NaN         NaN
# 670             NaN     NaN  NaN  ...    NaN        NaN         NaN
# 671             NaN     NaN  NaN  ...    NaN        NaN         NaN
# 672             NaN     NaN  NaN  ...    NaN        NaN         NaN
# 673             NaN     NaN  NaN  ...    NaN        NaN         NaN
#
#      Young Frankenstein  Young and Innocent  Zatoichi  Zodiac  eXistenZ  xXx  \
# 0                   NaN                 NaN       NaN     NaN       NaN  NaN
# 1                   NaN                 NaN       NaN     NaN       NaN  NaN
# 2                   NaN                 3.5       NaN     NaN       NaN  NaN
# 3                   5.0                 NaN       NaN     NaN       NaN  NaN
# 4                   NaN                 3.5       NaN     NaN       NaN  NaN
# ..                  ...                 ...       ...     ...       ...  ...
# 669                 NaN                 NaN       NaN     NaN       NaN  NaN
# 670                 NaN                 4.0       NaN     NaN       NaN  NaN
# 671                 NaN                 NaN       NaN     NaN       NaN  NaN
# 672                 NaN                 NaN       NaN     NaN       NaN  NaN
# 673                 NaN                 NaN       NaN     NaN       NaN  NaN
#
#      À nos amours
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 669           NaN
# 670           NaN
# 671           NaN
# 672           NaN
# 673           NaN
#
# [674 rows x 944 columns]

# %%
df_pivot.columns
# Out:
# '28 Days Later'

# %%
dic = {}

# %%
dic['a1'] = 1

# %%
dic['b2'] = 2

# %%
dic
# Out:
# {'a1': 1, 'b2': 2}

# %%
df_corr = pd.read_csv('df_corr.csv', index_col=0)

# %%
df_corr
# Out:
#                      28 Days Later       300  7 Virgins   8 Women  88 Minutes  \
# title
# 28 Days Later             1.000000  0.189100   0.214053  0.110950    0.296684
# 300                       0.189100  1.000000   0.153035  0.393691    0.320768
# 7 Virgins                 0.214053  0.153035   1.000000  0.201602    0.180496
# 8 Women                   0.110950  0.393691   0.201602  1.000000    0.150919
# 88 Minutes                0.296684  0.320768   0.180496  0.150919    1.000000
# ...                            ...       ...        ...       ...         ...
# Yankee Doodle Dandy       0.210222  0.195374   0.174086  0.143749    0.296615
# Young Adam                0.279453  0.270513   0.182075  0.225076    0.354789
# Young Frankenstein        0.203146  0.281256   0.222384  0.258531    0.345558
# Zatoichi                  0.006954  0.115508   0.121469  0.185540   -0.038943
# xXx                       0.186320  0.173415   0.115104  0.214417    0.243593
#
#                      A Bridge Too Far  A Close Shave  A Kiss Before Dying  \
# title
# 28 Days Later                0.014497       0.137849             0.341978
# 300                          0.118686       0.153659             0.130509
# 7 Virgins                    0.213251       0.229352             0.322558
# 8 Women                      0.180756       0.111424             0.194514
# 88 Minutes                   0.045695       0.094595             0.253203
# ...                               ...            ...                  ...
# Yankee Doodle Dandy          0.086264       0.159409             0.194484
# Young Adam                   0.083626       0.112623             0.236140
# Young Frankenstein           0.202837       0.135093             0.162884
# Zatoichi                     0.272984       0.140176            -0.056316
# xXx                          0.132562       0.273922             0.162931
#
#                      A Perfect Murder  A Tale of Two Cities  ...  \
# title                                                        ...
# 28 Days Later                0.103624              0.339376  ...
# 300                          0.091131              0.200073  ...
# 7 Virgins                    0.211946              0.194455  ...
# 8 Women                      0.094293              0.178048  ...
# 88 Minutes                   0.061813              0.346692  ...
# ...                               ...                   ...  ...
# Yankee Doodle Dandy          0.127682              0.224691  ...
# Young Adam                   0.056565              0.430057  ...
# Young Frankenstein           0.158284              0.252163  ...
# Zatoichi                     0.181660              0.102715  ...
# xXx                          0.238967              0.290602  ...
#
#                      What's New Pussycat?  While You Were Sleeping  \
# title
# 28 Days Later                    0.078391                 0.080935
# 300                              0.168064                 0.188818
# 7 Virgins                        0.154537                 0.170352
# 8 Women                          0.130355                 0.198973
# 88 Minutes                       0.069738                 0.067352
# ...                                   ...                      ...
# Yankee Doodle Dandy              0.160776                 0.091121
# Young Adam                       0.220426                 0.079497
# Young Frankenstein               0.313075                 0.142830
# Zatoichi                         0.282207                 0.333572
# xXx                              0.139024                 0.190172
#
#                      Willy Wonka & the Chocolate Factory  Wish You Were Here  \
# title
# 28 Days Later                                   0.316099            0.156420
# 300                                             0.257048            0.261245
# 7 Virgins                                       0.187914            0.272589
# 8 Women                                         0.148738            0.178505
# 88 Minutes                                      0.393844            0.230593
# ...                                                  ...                 ...
# Yankee Doodle Dandy                             0.222833            0.218490
# Young Adam                                      0.384634            0.290240
# Young Frankenstein                              0.278479            0.213465
# Zatoichi                                        0.092937            0.170534
# xXx                                             0.217843            0.191601
#
#                      Within the Woods  Yankee Doodle Dandy  Young Adam  \
# title
# 28 Days Later                0.086543             0.210222    0.279453
# 300                          0.137678             0.195374    0.270513
# 7 Virgins                    0.191204             0.174086    0.182075
# 8 Women                      0.156882             0.143749    0.225076
# 88 Minutes                   0.042947             0.296615    0.354789
# ...                               ...                  ...         ...
# Yankee Doodle Dandy          0.127338             1.000000    0.199108
# Young Adam                   0.133239             0.199108    1.000000
# Young Frankenstein           0.239771             0.265369    0.324355
# Zatoichi                     0.266387             0.099752    0.053825
# xXx                          0.200158             0.197308    0.177691
#
#                      Young Frankenstein  Zatoichi       xXx
# title
# 28 Days Later                  0.203146  0.006954  0.186320
# 300                            0.281256  0.115508  0.173415
# 7 Virgins                      0.222384  0.121469  0.115104
# 8 Women                        0.258531  0.185540  0.214417
# 88 Minutes                     0.345558 -0.038943  0.243593
# ...                                 ...       ...       ...
# Yankee Doodle Dandy            0.265369  0.099752  0.197308
# Young Adam                     0.324355  0.053825  0.177691
# Young Frankenstein             1.000000  0.244995  0.182261
# Zatoichi                       0.244995  1.000000  0.236278
# xXx                            0.182261  0.236278  1.000000
#
# [259 rows x 259 columns]

# %%
range(len(df_corr.columns))
# Out:
# range(0, 259)

# %%
import pickle
with open('url_dict.pickle', 'wb') as f:
    pickle.dump(url_dict, f)

# %%
chrome_path ='C:\\Users\\-\\Documents\\GitHub\\yh_seo\\project\\movie\\croll\chromedriver.exe'
base_url = "https://www.google.co.kr/imghp"

chrome_options = webdriver.ChromeOptions()
# chrome_options.add_argument('--headless') # 창 없는 모드
# headless 모드의 호환성을 위해 아래 옵션 추가(가끔 막는 웹이 있음)
#chrome_options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")
chrome_options.add_argument("lang=ko_KR") # 한국어
chrome_options.add_argument('window-size=1920x1080')
# chrome_options.add_argument('--no-sandbox')
# chrome_options.add_argument('--disable-dev-shm-usage')


driver = webdriver.Chrome(chrome_path,chrome_options=chrome_options)
driver.get(base_url)
driver.implicitly_wait(3) # element가 로드될 때까지 지정한 시간만큼 대기할 수 있도록 설정
driver.get_screenshot_as_file('google_screen.png')
driver.close()

# def selenium_scroll_option():
#     SCROLL_PAUSE_SEC = 3

#     # 스크롤 높이 가져옴
#     last_height = driver.execute_script("return document.body.scrollHeight")

#     while True:
#         # 끝까지 스크롤 다운
#         driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

#         # 1초 대기
#         time.sleep(SCROLL_PAUSE_SEC)

#         # 스크롤 다운 후 스크롤 높이 다시 가져옴
#         new_height = driver.execute_script("return document.body.scrollHeight")

#         if new_height == last_height:
#             break
#         last_height = new_height

choice_movie = df_corr.columns[0]

a= 'movie ' + choice_movie
image_name = 'amugona'
#b=int(input("몇 개 저장할래? : "))
driver = webdriver.Chrome(chrome_path)
driver.get('http://www.google.co.kr/imghp?hl=ko')
browser = driver.find_element_by_name("q")
browser.send_keys(a)
browser.send_keys(Keys.RETURN)

images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd") #  클래스 네임에서 공백은 .을 찍어줌
images_url = []
for i in images: 

    if i.get_attribute('src')!= None :
            images_url.append(i.get_attribute('src'))
    else :
        images_url.append(i.get_attribute('data-src'))
driver.close()

img = images_url[20]
print(img)
#url_dict = { choice_movie : img }
# Out:
# C:\Users\-\AppData\Local\Temp/ipykernel_1776/2230829026.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path,chrome_options=chrome_options)
# C:\Users\-\AppData\Local\Temp/ipykernel_1776/2230829026.py:14: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_path,chrome_options=chrome_options)
# C:\Users\-\AppData\Local\Temp/ipykernel_1776/2230829026.py:45: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# C:\Users\-\AppData\Local\Temp/ipykernel_1776/2230829026.py:47: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   browser = driver.find_element_by_name("q")
# C:\Users\-\AppData\Local\Temp/ipykernel_1776/2230829026.py:51: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd") #  클래스 네임에서 공백은 .을 찍어줌
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR_KOQmAjV7AFqAlIepAH6v5hLyUODUfUTATQ&usqp=CAU

# %%
images_url[0]
# Out:
# 'data:image/jpeg;base64,...'
